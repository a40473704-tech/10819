# %% [markdown]
# <a href="https://colab.research.google.com/github/a40473704-tech/10819/blob/main/20260907.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime, date,time
print('<디데이(D-day)프로그램>')
print()
year= int(input('연도를 입력하하세요:'))
month=int(input('월을 입력하세요:'))
day=int(input('일을 입력하세요'))
dt4=date(year,month,day)
today = date.today()
dday=(dt4-today).days
print(f'{year}년{month}월{day}일은{dday}일 남았습니다.')
# Out:
# <디데이(D-day)프로그램>
#
# 연도를 입력하하세요:2026
# 월을 입력하세요:9
# 일을 입력하세요7
# 2026년9월7일은0일 남았습니다.

# %%
print('=====회전 초밥 영수증=====')
print('접시 단가 개수 합계')
a1=int(input('빨간색 접시에 갯수:'))
b1=int(input('노란색 접시에 갯수:'))
c1=int(input('파란색 접시에 갯수:'))
d1=int(input('초록색 접시에 갯수:'))
a2=1000
b2=2000
c2=3000
d2=4000
print(f'빨간색\t{a1}\t{a2}\t{a1*a2}')
print(f'노란색\t{b1}\t{b2}\t{b1*b2}')
print(f'파란색\t{c1}\t{c2}\t{c1*c2}')
print(f'초록색\t{d1}\t{d2}\t{d1*d2}')
print('총가격                 19,000')
print('========================')
# Out:
# =====회전 초밥 영수증=====
# 접시 단가 개수 합계
# 빨간색 접시에 갯수2
# 노란색 접시에 갯수1
# 파란색 접시에 갯수3
# 초록색 접시에 갯수2
# 빨간색	2	1000	2000
# 노란색	1	2000	2000
# 파란색	3	3000	9000
# 초록색	2	4000	8000
# 총가격                 19,000
# ...
