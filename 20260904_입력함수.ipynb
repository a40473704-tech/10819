# %% [markdown]
# <a href="https://colab.research.google.com/github/a40473704-tech/10819/blob/main/20260904_%EC%9E%85%EB%A0%A5%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input('이름:')
b = input('나이:')
print(a, '님 안녕하세요?')
print(20+int(b), '년 후면 20살이시네요!')
# Out:
# 이름:임승후
# 나이:17
# 임승후 님 안녕하세요?
# 37 년 후면 20살이시네요!

# %%
print(7/3)
print(7//3)
print(7%3)
# Out:
# 2.3333333333333335
# 2
# 1

# %%
sce= int(input('시간을 초 단위로 입력하세요'))
m = sce // 60
s=sce%60
print(f'{m}분 {s}초')
# Out:
# 시간을 초 단위로 입력하세요30
# 0분 30초

# %%
print('################')
print('[한양과학기술고등학교 학생증]')
input('학번:')
input('성명:')
input('소속:')
print('위 사람은 본 학교에 학생임을 증명함')
print('################')
# Out:
# ################
# [한양과학기술고등학교 학생증]
# 학번:10819
# 성명:임승후
# 소속:한양공고
# 위 사람은 본 학교에 학생임을 증명함
# ################
